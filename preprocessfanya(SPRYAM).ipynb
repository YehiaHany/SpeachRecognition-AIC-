# %%
import os
import numpy as np
import pandas as pd
import librosa
from scipy.io import wavfile

# Define paths
train_audio_path = "C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train/"
adapt_audio_path = 'C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt/'
train_csv_path = 'C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv'
adapt_csv_path = 'C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv'
output_path = 'C:/Users/king/Downloads/MTC-ASR-Dataset-16K/preprocessed_data/'

# Ensure output path exists
os.makedirs(output_path, exist_ok=True)

# %%
train_df = pd.read_csv(train_csv_path)
adapt_df = pd.read_csv(adapt_csv_path)

print("Train CSV Columns: ", train_df.columns)
print("Adapt CSV Columns: ", adapt_df.columns)

# Display the first few rows of each CSV file
print(train_df.head())
print(adapt_df.head())
# Out:
# Train CSV Columns:  Index(['audio', 'transcript'], dtype='object')
# Adapt CSV Columns:  Index(['audio', 'transcript'], dtype='object')
#             audio                                         transcript
# 0  train_sample_0  على إنها عار في الوقت اللي كانت بتتعامل مع أخو...
# 1  train_sample_1  فأكيد ربنا عوضهم خير هو الراجل بيبقى ليه إختيا...
# 2  train_sample_2  زي دول كتيره بنشوفها النهارده في العالم وأصبحت...
# 3  train_sample_3  يعني مين اللي بيحط شروطها يعني أنا شايفه إني م...
# 4  train_sample_4  والله هي الموضوع مش كليب خلي بالك ولا أغنيه ال...
#                   audio                                         transcript
# 0  adapt_sample_0_clean                            شوفلنا المشوار ده يا حج
# 1  adapt_sample_1_clean  لأ للأسف دكتوره واحده بس بتعمل العمليه ديت عند...
# 2  adapt_sample_2_clean                        والراجل تبصله يعني إبن زمنه
# 3  adapt_sample_3_clean                       و أنت كيف عرفته أبترل يا عمي
# 4  adapt_sample_4_clean               ميعرفوش حاجه عن السوبر أه غير إنه لب

# %%
# Data augmentation functions
def add_noise(data, noise_factor=0.005):
    noise = np.random.randn(len(data))
    augmented_data = data + noise_factor * noise
    return augmented_data

def shift(data, shift_max=2, shift_direction='both'):
    shift = np.random.randint(shift_max)
    if shift_direction == 'right':
        shift = -shift
    elif shift_direction == 'both':
        direction = np.random.randint(0, 2)
        if direction == 1:
            shift = -shift
    augmented_data = np.roll(data, shift)
    return augmented_data

def stretch(data, rate=1.0):
    return librosa.effects.time_stretch(y=data, rate=rate)

# %%
import numpy as np
import librosa

# Feature extraction function
def extract_features(file_path, target_sr=16000, n_mfcc=13):
    try:
        audio, sr = librosa.load(file_path, sr=target_sr)
        
        # Data Augmentation
        audio = add_noise(audio)
        audio = shift(audio)
        audio = stretch(audio, rate=np.random.uniform(0.8, 1.2))

        # Adjust n_fft if audio length is shorter
        n_fft = min(len(audio), 512)  # Use 512 or the length of the audio, whichever is smaller

        # Feature extraction
        mfccs = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=n_mfcc, n_fft=n_fft)
        chroma = librosa.feature.chroma_stft(y=audio, sr=sr, n_fft=n_fft)
        mel = librosa.feature.melspectrogram(y=audio, sr=sr, n_fft=n_fft)
        contrast = librosa.feature.spectral_contrast(y=audio, sr=sr, n_fft=n_fft)
        tonnetz = librosa.feature.tonnetz(y=librosa.effects.harmonic(audio), sr=sr)
        
        # Combine features
        features = np.concatenate((
            np.mean(mfccs.T, axis=0),
            np.mean(chroma.T, axis=0),
            np.mean(mel.T, axis=0),
            np.mean(contrast.T, axis=0),
            np.mean(tonnetz.T, axis=0)
        ))
        
        return features, None  # Return features and no error
    except Exception as e:
        return None, str(e)  # Return None and error message

# %%
from tqdm import tqdm
def preprocess_and_save_data(csv_path, audio_path, output_file):
    df = pd.read_csv(csv_path)
    print(f"First 5 rows of {csv_path}:")
    print(df.head())

    features_list = []
    labels = []
    errors = []

    for idx, row in tqdm(df.iterrows(), total=len(df), desc=f"Processing {csv_path}"):
        try:
            file_path = os.path.join(audio_path, f"{row['audio']}.wav")
            features, error = extract_features(file_path)
            if features is not None:
                features_list.append(features)
                labels.append(row['transcript'])
                
            else:
                errors.append(f"Error processing {file_path}: {error}")
        except Exception as e:
            errors.append(f"Exception processing {file_path}: {str(e)}")

    features_array = np.array(features_list)
    labels_array = np.array(labels)

    print(f"Final features array shape: {features_array.shape}")
    print(f"Final labels array shape: {labels_array.shape}")
    print(f"Number of errors: {len(errors)}")

    np.savez_compressed(output_file, features=features_array, labels=labels_array, errors=errors)
    print(f"Saved preprocessed data to {output_file}")

# Preprocess train and adapt datasets
preprocess_and_save_data(train_csv_path, train_audio_path, os.path.join(output_path, 'train_data.npz'))
preprocess_and_save_data(adapt_csv_path, adapt_audio_path, os.path.join(output_path, 'adapt_data.npz'))
# Out:
# First 5 rows of C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:
#             audio                                         transcript
# 0  train_sample_0  على إنها عار في الوقت اللي كانت بتتعامل مع أخو...
# 1  train_sample_1  فأكيد ربنا عوضهم خير هو الراجل بيبقى ليه إختيا...
# 2  train_sample_2  زي دول كتيره بنشوفها النهارده في العالم وأصبحت...
# 3  train_sample_3  يعني مين اللي بيحط شروطها يعني أنا شايفه إني م...
# 4  train_sample_4  والله هي الموضوع مش كليب خلي بالك ولا أغنيه ال...
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:   4%|▎         | 1870/50715 [12:54<4:52:19,  2.78it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=444
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:  13%|█▎        | 6375/50715 [42:28<4:34:24,  2.69it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=383
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:  13%|█▎        | 6418/50715 [42:46<4:38:29,  2.65it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=503
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:  21%|██        | 10613/50715 [1:10:44<4:07:48,  2.70it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=337
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:  23%|██▎       | 11552/50715 [1:16:54<5:03:02,  2.15it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=471
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:  23%|██▎       | 11889/50715 [1:19:10<4:15:24,  2.53it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=362
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:  24%|██▍       | 12119/50715 [1:20:44<5:04:49,  2.11it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=277
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:  31%|███       | 15642/50715 [1:44:11<3:38:53,  2.67it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=389
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:  31%|███       | 15772/50715 [1:45:02<3:35:34,  2.70it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=450
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:  51%|█████     | 25665/50715 [2:50:04<2:48:29,  2.48it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=315
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:  53%|█████▎    | 27074/50715 [2:59:25<2:05:53,  3.13it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=421
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:  60%|██████    | 30668/50715 [3:23:06<2:13:32,  2.50it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=274
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:  63%|██████▎   | 32197/50715 [3:32:55<1:44:07,  2.96it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=460
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:  65%|██████▍   | 32750/50715 [3:36:27<1:59:28,  2.51it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=413
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:  67%|██████▋   | 33736/50715 [3:42:44<1:41:01,  2.80it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=372
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:  74%|███████▍  | 37555/50715 [4:07:42<1:35:40,  2.29it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=265
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv:  79%|███████▉  | 40033/50715 [4:24:10<1:13:52,  2.41it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=307
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/train.csv: 100%|██████████| 50715/50715 [5:34:25<00:00,  2.53it/s]
# Final features array shape: (50715, 166)
# Final labels array shape: (50715,)
# Number of errors: 0
# Saved preprocessed data to C:/Users/king/Downloads/MTC-ASR-Dataset-16K/preprocessed_data/train_data.npz
# First 5 rows of C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:
#                   audio                                         transcript
# 0  adapt_sample_0_clean                            شوفلنا المشوار ده يا حج
# 1  adapt_sample_1_clean  لأ للأسف دكتوره واحده بس بتعمل العمليه ديت عند...
# 2  adapt_sample_2_clean                        والراجل تبصله يعني إبن زمنه
# 3  adapt_sample_3_clean                       و أنت كيف عرفته أبترل يا عمي
# 4  adapt_sample_4_clean               ميعرفوش حاجه عن السوبر أه غير إنه لب
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   0%|          | 0/2199 [00:00<?, ?it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=361
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   1%|          | 11/2199 [00:04<17:57,  2.03it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=354
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   1%|          | 13/2199 [00:04<11:44,  3.10it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=408
#   warnings.warn(
# c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=204
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   1%|          | 20/2199 [00:06<10:09,  3.58it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=483
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   1%|▏         | 31/2199 [00:11<14:50,  2.44it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=511
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   2%|▏         | 38/2199 [00:14<13:45,  2.62it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=342
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   2%|▏         | 39/2199 [00:14<11:24,  3.16it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=474
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   2%|▏         | 43/2199 [00:16<17:27,  2.06it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=478
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   2%|▏         | 46/2199 [00:17<10:44,  3.34it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=491
#   warnings.warn(
# c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=246
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   2%|▏         | 47/2199 [00:17<08:46,  4.09it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=366
#   warnings.warn(
# c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=183
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   2%|▏         | 52/2199 [00:18<09:12,  3.88it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=308
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   2%|▏         | 54/2199 [00:19<12:06,  2.95it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=497
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   3%|▎         | 55/2199 [00:19<10:18,  3.47it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=438
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   3%|▎         | 56/2199 [00:19<08:52,  4.03it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=365
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   3%|▎         | 60/2199 [00:21<16:51,  2.12it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=325
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   3%|▎         | 61/2199 [00:22<13:12,  2.70it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=376
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   3%|▎         | 66/2199 [00:24<14:37,  2.43it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=394
#   warnings.warn(
# c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=197
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   4%|▎         | 77/2199 [00:27<17:36,  2.01it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=303
#   warnings.warn(
# c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=152
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   4%|▍         | 84/2199 [00:30<11:46,  3.00it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=484
#   warnings.warn(
# c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=242
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   4%|▍         | 90/2199 [00:31<10:47,  3.26it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=489
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   4%|▍         | 93/2199 [00:33<12:22,  2.84it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=428
#   warnings.warn(
# c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=214
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   4%|▍         | 95/2199 [00:33<10:12,  3.43it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=329
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   4%|▍         | 97/2199 [00:34<11:10,  3.14it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=510
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   5%|▍         | 100/2199 [00:34<10:24,  3.36it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=509
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   5%|▍         | 104/2199 [00:37<19:38,  1.78it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=282
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   5%|▍         | 105/2199 [00:37<15:15,  2.29it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=480
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   5%|▌         | 110/2199 [00:39<12:34,  2.77it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=464
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   5%|▌         | 118/2199 [00:41<08:31,  4.07it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=402
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   6%|▌         | 126/2199 [00:43<09:49,  3.51it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=353
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   6%|▌         | 127/2199 [00:43<08:25,  4.10it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=359
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   6%|▌         | 136/2199 [00:46<10:08,  3.39it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=448
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   6%|▋         | 142/2199 [00:49<12:17,  2.79it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=334
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:   7%|▋         | 144/2199 [00:49<10:51,  3.15it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  84%|████████▎ | 1837/2199 [09:21<01:06,  5.44it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=323
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  84%|████████▎ | 1838/2199 [09:22<01:00,  5.99it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=296
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  84%|████████▍ | 1853/2199 [09:25<01:07,  5.16it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=419
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  84%|████████▍ | 1855/2199 [09:25<01:17,  4.45it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=271
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  85%|████████▍ | 1859/2199 [09:26<01:06,  5.12it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=213
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  85%|████████▍ | 1862/2199 [09:26<00:47,  7.13it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=238
#   warnings.warn(
# c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=119
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  85%|████████▍ | 1863/2199 [09:26<00:46,  7.21it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=123
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  86%|████████▋ | 1898/2199 [09:35<01:17,  3.89it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=114
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  86%|████████▋ | 1901/2199 [09:36<01:08,  4.34it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=403
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  88%|████████▊ | 1927/2199 [09:42<01:56,  2.34it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=162
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  88%|████████▊ | 1932/2199 [09:43<00:53,  5.04it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=236
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  88%|████████▊ | 1933/2199 [09:43<00:46,  5.71it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=363
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  88%|████████▊ | 1943/2199 [09:45<00:48,  5.25it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=355
#   warnings.warn(
# c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=178
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  89%|████████▊ | 1948/2199 [09:46<00:35,  7.07it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=490
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  89%|████████▉ | 1958/2199 [09:48<01:03,  3.77it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=139
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  90%|████████▉ | 1972/2199 [09:52<00:58,  3.88it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=94
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  90%|█████████ | 1981/2199 [09:54<00:53,  4.10it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=452
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  90%|█████████ | 1982/2199 [09:54<00:47,  4.60it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=253
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  90%|█████████ | 1989/2199 [09:56<00:55,  3.80it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=88
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  91%|█████████ | 1996/2199 [09:57<00:53,  3.78it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=479
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  92%|█████████▏| 2015/2199 [10:00<00:34,  5.34it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=125
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  93%|█████████▎| 2037/2199 [10:09<01:13,  2.21it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=138
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  93%|█████████▎| 2056/2199 [10:16<00:43,  3.29it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=229
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  95%|█████████▌| 2094/2199 [10:24<00:20,  5.19it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=175
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  99%|█████████▊| 2168/2199 [10:52<00:07,  3.95it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=234
#   warnings.warn(
# c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=117
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv:  99%|█████████▉| 2173/2199 [10:54<00:08,  3.17it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=330
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv: 100%|█████████▉| 2193/2199 [11:00<00:01,  5.59it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=177
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv: 100%|█████████▉| 2195/2199 [11:00<00:00,  5.08it/s]c:\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=121
#   warnings.warn(
# Processing C:/Users/king/Downloads/MTC-ASR-Dataset-16K/adapt.csv: 100%|██████████| 2199/2199 [11:02<00:00,  3.32it/s]
# Final features array shape: (2199, 166)
# Final labels array shape: (2199,)
# Number of errors: 0
# Saved preprocessed data to C:/Users/king/Downloads/MTC-ASR-Dataset-16K/preprocessed_data/adapt_data.npz

# %%
import numpy as np
# Load the preprocessed data
train_data = np.load("C:/Users/king/Downloads/MTC-ASR-Dataset-16K/preprocessed_data/train_data.npz")
train_features = train_data['features']
train_labels = train_data['labels']

adapt_data = np.load("C:/Users/king/Downloads/MTC-ASR-Dataset-16K/preprocessed_data/adapt_data.npz")
adapt_features = adapt_data['features']
adapt_labels = adapt_data['labels']

# %%
print("Train data shape:", train_features.shape)
print("Adaptation data shape:", adapt_features.shape)
# Out:
# Train data shape: (50715, 166)
# Adaptation data shape: (2199, 166)

# %%
print(train_data.files)
print(train_data['features'].shape)
print(train_data['labels'].shape)
# Out:
# ['features', 'labels', 'errors']
# (50715, 166)
# (50715,)
